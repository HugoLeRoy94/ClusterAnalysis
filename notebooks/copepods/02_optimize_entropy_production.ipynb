# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append('../../')

import src.viz

#sns.set(style="white", context="notebook")

# %%
df = pd.read_csv('../../data/copepods/interim/entropy_scan_1.csv')

# %% [markdown]
# Look at the entropy production using absolute value of the torsion angle.

# %%
df2 = pd.read_csv('../../data/copepods/interim/entropy_scan.csv')

# %%
fig,ax = plt.subplots(ncols=2,figsize=(14,7))

for K, group in df2.groupby("K"):
    ax[0].plot(group["n_clusters"], group["entropy_rate"], marker='o', label=f"K={K}")
    #ax[1].plot(group["n_clusters"], group["entropy_rate"] - 1/4*np.log(group['n_clusters']), marker='o', label=f"K={K}")
    #ax[1].plot(group["n_clusters"], np.gradient(group["entropy_rate"],group["n_clusters"]), marker='o', label=f"K={K}")
ax[0].set_xlabel("Number of clusters ")
ax[0].set_ylabel("Entropy rate (bits)")
ax[0].set_title("Entropy rate vs number of clusters")
#ax[0].set_xlim(0,5)
ax[0].legend()
ax[0].set_xscale('log')

ax[1].set_xlabel("Number of clusters ")
ax[1].set_ylabel("derivative of the Entropy rate (bits)")
#ax[1].set_ylim(0,1000)
ax[1].set_title("Entropy rate vs number of clusters")
#ax[1].set_xlim(0,5)
ax[1].legend()
ax[1].set_xscale('log')
# Out:
# /tmp/ipykernel_4280/2705632474.py:19: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax[1].legend()

# %% [markdown]
# We select K = N_clusters = 30
